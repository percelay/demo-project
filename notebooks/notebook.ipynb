# %%
import numpy as np

# Generate fake data
data = np.random.normal(loc=0, scale=1, size=100)

# Calculate summary statistics
mean = np.mean(data)
median = np.median(data)
std_dev = np.std(data)
min_val = np.min(data)
max_val = np.max(data)

# Print the summary statistics
print("Mean:", mean)
print("Median:", median)
print("Standard Deviation:", std_dev)
print("Minimum Value:", min_val)
print("Maximum Value:", max_val)
# Out:
# Mean: -0.07356119686659718
# Median: -0.032824459126439935
# Standard Deviation: 0.9335460924402373
# Minimum Value: -2.2476813123255934
# Maximum Value: 2.294041604504293
